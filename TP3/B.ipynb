# %%
import numpy as np
import matplotlib.pyplot as plt
import math as m
import pandas as pd
import scipy as sp
from statsmodels.tsa.stattools import adfuller

# %%
array = pd.DataFrame(data = np.loadtxt("lisbon_ro_t1.txt"), columns = ['Temp (ºC)'])
x = np.linspace(1980, 2018, len(array))
plt.plot(x, array, 'k')

result = adfuller(array)
print(result)
# Out:
# (-1.3107052163190707, 0.6242605438457701, 24, 1379, {'1%': -3.4351009168670035, '5%': -2.863638180853028, '10%': -2.5678870681532424}, 4986.583264622917)
